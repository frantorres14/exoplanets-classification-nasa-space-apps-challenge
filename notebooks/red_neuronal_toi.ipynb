# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

from tools import preprocesamiento

# %% [markdown]
# ## Cargar y preprocesar los datos

# %%
X_train, X_test, y_train, y_test, X_candidate = preprocesamiento(path='TOI.csv', dataset='toi')

# %% [markdown]
# ## Definir el modelo

# %%
model = tf.keras.Sequential([
    layers.Dense(64, input_shape=(X_train.shape[1],)),
    layers.Activation('relu'),
    layers.Dropout(0.5),
    #layers.BatchNormalization(),

    layers.Dense(64),
    layers.Activation('relu'),
    layers.BatchNormalization(),

    layers.Dense(32),
    layers.Activation('relu'),
    #layers.BatchNormalization(),

    layers.Dense(1),
    layers.Activation('sigmoid')
])
# Out:
# c:\Users\yamil\miniconda3\envs\ml\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,873 (30.75 KB)
#  Trainable params: 7,745 (30.25 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# ## Compilar y entrenar el modelo

# %%
model.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=0.0005),
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5411 - loss: 0.7888 - val_accuracy: 0.6303 - val_loss: 0.6541
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6272 - loss: 0.6490 - val_accuracy: 0.7149 - val_loss: 0.6086
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6690 - loss: 0.6030 - val_accuracy: 0.7327 - val_loss: 0.5721
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7121 - loss: 0.5577 - val_accuracy: 0.7483 - val_loss: 0.5445
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7114 - loss: 0.5669 - val_accuracy: 0.7661 - val_loss: 0.5282
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7047 - loss: 0.5776 - val_accuracy: 0.7617 - val_loss: 0.5200
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7261 - loss: 0.5452 - val_accuracy: 0.7751 - val_loss: 0.5104
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7113 - loss: 0.5576 - val_accuracy: 0.7728 - val_loss: 0.5071
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7096 - loss: 0.5517 - val_accuracy: 0.7751 - val_loss: 0.4985
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7322 - loss: 0.5255 - val_accuracy: 0.7728 - val_loss: 0.4939
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7102 - loss: 0.5403 - val_accuracy: 0.7862 - val_loss: 0.4876
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7161 - loss: 0.5349 - val_accuracy: 0.7773 - val_loss: 0.4856
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7347 - loss: 0.5266 - val_accuracy: 0.7773 - val_loss: 0.4868
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5300 - val_accuracy: 0.7773 - val_loss: 0.4814
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7504 - loss: 0.5044 - val_accuracy: 0.7840 - val_loss: 0.4793
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7344 - loss: 0.5205 - val_accuracy: 0.7840 - val_loss: 0.4744
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7316 - loss: 0.5194 - val_accuracy: 0.7817 - val_loss: 0.4734
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7774 - loss: 0.4955 - val_accuracy: 0.7906 - val_loss: 0.4708
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7695 - loss: 0.4904 - val_accuracy: 0.7884 - val_loss: 0.4688
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7517 - loss: 0.5072 - val_accuracy: 0.7862 - val_loss: 0.4653
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7733 - loss: 0.4759 - val_accuracy: 0.7929 - val_loss: 0.4677
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7396 - loss: 0.5094 - val_accuracy: 0.7951 - val_loss: 0.4676
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7777 - loss: 0.4689 - val_accuracy: 0.7906 - val_loss: 0.4613
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7780 - loss: 0.4797 - val_accuracy: 0.8018 - val_loss: 0.4599
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7787 - loss: 0.4751 - val_accuracy: 0.7951 - val_loss: 0.4598
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7557 - loss: 0.4824 - val_accuracy: 0.8040 - val_loss: 0.4585
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7713 - loss: 0.4814 - val_accuracy: 0.8107 - val_loss: 0.4539
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7728 - loss: 0.4890 - val_accuracy: 0.8018 - val_loss: 0.4587
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7651 - loss: 0.4926 - val_accuracy: 0.7996 - val_loss: 0.4543
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - loss: 0.4569 - val_accuracy: 0.8018 - val_loss: 0.4539
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7664 - loss: 0.4703 - val_accuracy: 0.8018 - val_loss: 0.4537
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7881 - loss: 0.4468 - val_accuracy: 0.7973 - val_loss: 0.4516
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7735 - loss: 0.4748 - val_accuracy: 0.8085 - val_loss: 0.4512
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7892 - loss: 0.4681 - val_accuracy: 0.8040 - val_loss: 0.4485
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8081 - loss: 0.4326 - val_accuracy: 0.8062 - val_loss: 0.4449
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7750 - loss: 0.4481 - val_accuracy: 0.8040 - val_loss: 0.4417
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7987 - loss: 0.4480 - val_accuracy: 0.8062 - val_loss: 0.4414
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7993 - loss: 0.4195 - val_accuracy: 0.8129 - val_loss: 0.4397
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7842 - loss: 0.4489 - val_accuracy: 0.8129 - val_loss: 0.4408
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8045 - loss: 0.4262 - val_accuracy: 0.8062 - val_loss: 0.4386
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8113 - loss: 0.4279 - val_accuracy: 0.8040 - val_loss: 0.4393
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7833 - loss: 0.4368 - val_accuracy: 0.8062 - val_loss: 0.4341
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7972 - loss: 0.4291 - val_accuracy: 0.8062 - val_loss: 0.4353
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8117 - loss: 0.4294 - val_accuracy: 0.8062 - val_loss: 0.4345
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8070 - loss: 0.4330 - val_accuracy: 0.8085 - val_loss: 0.4344
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8019 - loss: 0.4361 - val_accuracy: 0.8129 - val_loss: 0.4300
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7802 - loss: 0.4486 - val_accuracy: 0.8107 - val_loss: 0.4314
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7966 - loss: 0.4147 - val_accuracy: 0.8174 - val_loss: 0.4284
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7916 - loss: 0.4470 - val_accuracy: 0.8129 - val_loss: 0.4266
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8080 - loss: 0.4222 - val_accuracy: 0.8151 - val_loss: 0.4227
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7931 - loss: 0.4444 - val_accuracy: 0.8107 - val_loss: 0.4248
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8019 - loss: 0.4334 - val_accuracy: 0.8107 - val_loss: 0.4239
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8068 - loss: 0.4164 - val_accuracy: 0.8129 - val_loss: 0.4268
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8185 - loss: 0.4076 - val_accuracy: 0.8196 - val_loss: 0.4240
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8055 - loss: 0.4284 - val_accuracy: 0.8129 - val_loss: 0.4243
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8015 - loss: 0.4376 - val_accuracy: 0.8196 - val_loss: 0.4203
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8003 - loss: 0.4316 - val_accuracy: 0.8174 - val_loss: 0.4202
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8006 - loss: 0.4212 - val_accuracy: 0.8129 - val_loss: 0.4222
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7977 - loss: 0.4328 - val_accuracy: 0.8129 - val_loss: 0.4209
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8121 - loss: 0.4178 - val_accuracy: 0.8129 - val_loss: 0.4201
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8081 - loss: 0.4118 - val_accuracy: 0.8151 - val_loss: 0.4179
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8042 - loss: 0.4236 - val_accuracy: 0.8129 - val_loss: 0.4140
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4141 - val_accuracy: 0.8174 - val_loss: 0.4161
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8126 - loss: 0.4182 - val_accuracy: 0.8196 - val_loss: 0.4136
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8073 - loss: 0.4231 - val_accuracy: 0.8129 - val_loss: 0.4143
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8134 - loss: 0.4097 - val_accuracy: 0.8285 - val_loss: 0.4135
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8115 - loss: 0.4191 - val_accuracy: 0.8218 - val_loss: 0.4127
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8122 - loss: 0.4111 - val_accuracy: 0.8241 - val_loss: 0.4113
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8337 - loss: 0.3818 - val_accuracy: 0.8196 - val_loss: 0.4088
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8238 - loss: 0.3860 - val_accuracy: 0.8241 - val_loss: 0.4071
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8225 - loss: 0.3998 - val_accuracy: 0.8174 - val_loss: 0.4113
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8110 - loss: 0.4029 - val_accuracy: 0.8218 - val_loss: 0.4082
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8217 - loss: 0.3950 - val_accuracy: 0.8174 - val_loss: 0.4096
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8310 - loss: 0.3884 - val_accuracy: 0.8196 - val_loss: 0.4091
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8372 - loss: 0.3996 - val_accuracy: 0.8196 - val_loss: 0.4112
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8183 - loss: 0.3963 - val_accuracy: 0.8174 - val_loss: 0.4143
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8153 - loss: 0.3939 - val_accuracy: 0.8151 - val_loss: 0.4115
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8072 - loss: 0.4196 - val_accuracy: 0.8196 - val_loss: 0.4102
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8089 - loss: 0.3989 - val_accuracy: 0.8263 - val_loss: 0.4096
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8234 - loss: 0.3813 - val_accuracy: 0.8241 - val_loss: 0.4099
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8365 - loss: 0.3718 - val_accuracy: 0.8218 - val_loss: 0.4077
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8352 - loss: 0.3992 - val_accuracy: 0.8241 - val_loss: 0.4054
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8212 - loss: 0.3826 - val_accuracy: 0.8307 - val_loss: 0.4010
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8219 - loss: 0.3981 - val_accuracy: 0.8374 - val_loss: 0.3995
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8492 - loss: 0.3572 - val_accuracy: 0.8307 - val_loss: 0.3989
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8169 - loss: 0.3969 - val_accuracy: 0.8352 - val_loss: 0.4009
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8306 - loss: 0.3932 - val_accuracy: 0.8307 - val_loss: 0.4023
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8142 - loss: 0.4134 - val_accuracy: 0.8263 - val_loss: 0.4048
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8315 - loss: 0.3930 - val_accuracy: 0.8263 - val_loss: 0.4061
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8343 - loss: 0.3683 - val_accuracy: 0.8263 - val_loss: 0.4040
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8146 - loss: 0.3906 - val_accuracy: 0.8330 - val_loss: 0.4018
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8336 - loss: 0.3620 - val_accuracy: 0.8330 - val_loss: 0.3978
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8296 - loss: 0.3865 - val_accuracy: 0.8441 - val_loss: 0.3945
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8233 - loss: 0.3764 - val_accuracy: 0.8352 - val_loss: 0.3965
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8449 - loss: 0.3713 - val_accuracy: 0.8330 - val_loss: 0.3982
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8332 - loss: 0.3668 - val_accuracy: 0.8307 - val_loss: 0.3991
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8280 - loss: 0.3922 - val_accuracy: 0.8374 - val_loss: 0.3940
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8334 - loss: 0.3744 - val_accuracy: 0.8374 - val_loss: 0.3947
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8466 - loss: 0.3526 - val_accuracy: 0.8441 - val_loss: 0.3943
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.3806 - val_accuracy: 0.8352 - val_loss: 0.3966

# %% [markdown]
# ## Evaluar el modelo

# %%
def calcular_metricas(model, X, y):
    #Probabilidades predichas
    y_prob = model.predict(X, verbose=0).flatten()

    #Predicción de clase
    y_pred = (y_prob > 0.5).astype(int)
    y_true = y.flatten() if y.ndim > 1 else y

    CM = confusion_matrix(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    roc_auc = roc_auc_score(y_true, y_prob)

    return CM, accuracy, precision, recall, f1, roc_auc


def evaluar_modelo(model, X_train, y_train, X_test, y_test):
    cm_train, acc_train, prec_train, rec_train, f1_train, roc_train = calcular_metricas(model, X_train, y_train)
    cm_test, acc_test, prec_test, rec_test, f1_test, roc_test = calcular_metricas(model, X_test, y_test)

    clases = ['FALSE POSITIVE', 'CONFIRMED']

    fig, ax = plt.subplots(1, 2, figsize=(12, 6))

    sns.heatmap(cm_train, annot=True, fmt='d', cmap='BuPu',
                xticklabels=clases, yticklabels=clases,
                ax=ax[0], annot_kws={'size': 10})
    ax[0].set_title('TOI - Train', fontsize=14)
    ax[0].set_xlabel('Predicho', fontsize=12)
    ax[0].set_ylabel('Real', fontsize=12)
    ax[0].tick_params(labelsize=11)
    ax[0].text(0.45, -0.12, f'\nAccuracy: {acc_train:.4f} | Precisión: {prec_train:.4f}\nRecall: {rec_train:.4f} | F1-Score: {f1_train:.4f}\nROC-AUC: {roc_train:.4f}',
            transform=ax[0].transAxes, ha='center', fontsize=11, va='top')

    sns.heatmap(cm_test, annot=True, fmt='d', cmap='BuPu',
                xticklabels=clases, yticklabels=clases,
                ax=ax[1], annot_kws={'size': 10})
    ax[1].set_title('TOI - Test', fontsize=14)
    ax[1].set_xlabel('Predicho', fontsize=12)
    ax[1].set_ylabel('Real', fontsize=12)
    ax[1].tick_params(labelsize=11)
    ax[1].text(0.45, -0.12, f'\nAccuracy: {acc_test:.4f} | Precisión: {prec_test:.4f}\nRecall: {rec_test:.4f} | F1-Score: {f1_test:.4f}\nROC-AUC: {roc_test:.4f}',
            transform=ax[1].transAxes, ha='center', fontsize=11, va='top')

    plt.tight_layout()
    plt.subplots_adjust(wspace=0.25) 
    plt.savefig('CM_toi.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
evaluar_modelo(model, X_train, y_train, X_test, y_test)

# %% [markdown]
# ## Realizar predicciones para los candidatos

# %%
def predecir_exoplanetas(model, X):
    prob_confirmed = model.predict(X).flatten() #Probabilidad de ser CONFIRMED
    prob_fp = 1 - prob_confirmed #Probabilidad de ser FALSE POSITIVE
    
    #Predicciones
    preds = (prob_confirmed >= 0.5).astype(int)
    clases = {0: 'FALSE POSITIVE', 1: 'CONFIRMED'}
    predicciones = np.array([clases[p] for p in preds])

    return prob_fp, prob_confirmed, predicciones

# %%
prob_fp, prob_conf, predicciones = predecir_exoplanetas(model, X_candidate)
for i in range(X_candidate.shape[0]):
    if predicciones[i] == 'FALSE POSITIVE':
        print(f'Clase predicha: {predicciones[i]}, Probabilidad: {prob_fp[i]:.4f}')
    else:
        print(f'Clase predicha: {predicciones[i]}, Probabilidad: {prob_conf[i]:.4f}')
# Out:
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9869
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5913
# Clase predicha: CONFIRMED, Probabilidad: 0.7507
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5805
# Clase predicha: CONFIRMED, Probabilidad: 0.8952
# Clase predicha: CONFIRMED, Probabilidad: 0.9855
# Clase predicha: CONFIRMED, Probabilidad: 0.9985
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8935
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8350
# Clase predicha: CONFIRMED, Probabilidad: 0.7102
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9943
# Clase predicha: CONFIRMED, Probabilidad: 0.5597
# Clase predicha: CONFIRMED, Probabilidad: 0.6815
# Clase predicha: CONFIRMED, Probabilidad: 0.7663
# Clase predicha: CONFIRMED, Probabilidad: 0.6495
# Clase predicha: CONFIRMED, Probabilidad: 0.7098
# Clase predicha: CONFIRMED, Probabilidad: 0.5911
# Clase predicha: CONFIRMED, Probabilidad: 0.8774
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7978
# Clase predicha: CONFIRMED, Probabilidad: 0.9611
# Clase predicha: CONFIRMED, Probabilidad: 0.5656
# Clase predicha: CONFIRMED, Probabilidad: 0.9074
# Clase predicha: CONFIRMED, Probabilidad: 0.7770
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9809
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9542
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9228
# Clase predicha: CONFIRMED, Probabilidad: 0.7810
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9648
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6054
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5287
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9803
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9898
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9923
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9689
# Clase predicha: CONFIRMED, Probabilidad: 0.8504
# Clase predicha: CONFIRMED, Probabilidad: 0.7293
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5500
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7656
# Clase predicha: CONFIRMED, Probabilidad: 0.8083
# Clase predicha: CONFIRMED, Probabilidad: 0.9692
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6922
# Clase predicha: CONFIRMED, Probabilidad: 0.8252
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8678
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9673
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8164
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7394
# Clase predicha: CONFIRMED, Probabilidad: 0.7872
# Clase predicha: CONFIRMED, Probabilidad: 0.9748
# Clase predicha: CONFIRMED, Probabilidad: 0.5160
# Clase predicha: CONFIRMED, Probabilidad: 0.6928
# Clase predicha: CONFIRMED, Probabilidad: 0.6790
# Clase predicha: CONFIRMED, Probabilidad: 0.6776
# Clase predicha: CONFIRMED, Probabilidad: 0.8767
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8301
# Clase predicha: CONFIRMED, Probabilidad: 0.5321
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5552
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9624
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8141
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5373
# Clase predicha: CONFIRMED, Probabilidad: 0.7244
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8068
# Clase predicha: CONFIRMED, Probabilidad: 0.7086
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9464
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6570
# Clase predicha: CONFIRMED, Probabilidad: 0.9547
# Clase predicha: CONFIRMED, Probabilidad: 0.9283
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6618
# Clase predicha: CONFIRMED, Probabilidad: 0.7279
# Clase predicha: CONFIRMED, Probabilidad: 0.6879
# Clase predicha: CONFIRMED, Probabilidad: 0.9382
# Clase predicha: CONFIRMED, Probabilidad: 0.7671
# Clase predicha: CONFIRMED, Probabilidad: 0.7866
# Clase predicha: CONFIRMED, Probabilidad: 0.9529
# Clase predicha: CONFIRMED, Probabilidad: 0.7989
# Clase predicha: CONFIRMED, Probabilidad: 0.9756
# Clase predicha: CONFIRMED, Probabilidad: 0.6300
# Clase predicha: CONFIRMED, Probabilidad: 0.6309
# Clase predicha: CONFIRMED, Probabilidad: 0.7735
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7925
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7742
# Clase predicha: CONFIRMED, Probabilidad: 0.8266
# Clase predicha: CONFIRMED, Probabilidad: 0.8273
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7394
# Clase predicha: CONFIRMED, Probabilidad: 0.7149
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6505
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5705
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9977
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9788
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6853
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6574
# Clase predicha: CONFIRMED, Probabilidad: 0.8928
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6011
# Clase predicha: CONFIRMED, Probabilidad: 0.7753
# Clase predicha: CONFIRMED, Probabilidad: 0.8051
# Clase predicha: CONFIRMED, Probabilidad: 0.8339
# Clase predicha: CONFIRMED, Probabilidad: 0.7586
# Clase predicha: CONFIRMED, Probabilidad: 0.8593
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8820
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5362
# Clase predicha: CONFIRMED, Probabilidad: 0.6737
# Clase predicha: CONFIRMED, Probabilidad: 0.9164
# Clase predicha: CONFIRMED, Probabilidad: 0.8645
# Clase predicha: CONFIRMED, Probabilidad: 0.5210
# Clase predicha: CONFIRMED, Probabilidad: 0.9079
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5528
# Clase predicha: CONFIRMED, Probabilidad: 0.9308
# Clase predicha: CONFIRMED, Probabilidad: 0.8405
# Clase predicha: CONFIRMED, Probabilidad: 0.7028
# Clase predicha: CONFIRMED, Probabilidad: 0.8724
# Clase predicha: CONFIRMED, Probabilidad: 0.8246
# Clase predicha: CONFIRMED, Probabilidad: 0.8849
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9803
# Clase predicha: CONFIRMED, Probabilidad: 0.8279
# Clase predicha: CONFIRMED, Probabilidad: 0.5905
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6305
# Clase predicha: CONFIRMED, Probabilidad: 0.7655
# Clase predicha: CONFIRMED, Probabilidad: 0.7896
# Clase predicha: CONFIRMED, Probabilidad: 0.9172
# Clase predicha: CONFIRMED, Probabilidad: 0.7033
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5364
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9586
# Clase predicha: CONFIRMED, Probabilidad: 0.7256
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9618
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9812
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9974
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8620
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9967
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9907
# Clase predicha: CONFIRMED, Probabilidad: 0.8604
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7957
# Clase predicha: CONFIRMED, Probabilidad: 0.6177
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8963
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9638
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8557
# Clase predicha: CONFIRMED, Probabilidad: 0.6367
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9907
# Clase predicha: CONFIRMED, Probabilidad: 0.8677
# Clase predicha: CONFIRMED, Probabilidad: 0.8531
# Clase predicha: CONFIRMED, Probabilidad: 0.5247
# Clase predicha: CONFIRMED, Probabilidad: 0.6276
# Clase predicha: CONFIRMED, Probabilidad: 0.9452
# Clase predicha: CONFIRMED, Probabilidad: 0.8127
# Clase predicha: CONFIRMED, Probabilidad: 0.5964
# Clase predicha: CONFIRMED, Probabilidad: 0.9798
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9655
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9655
# Clase predicha: CONFIRMED, Probabilidad: 0.5238
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7383
# Clase predicha: CONFIRMED, Probabilidad: 0.5032
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5888
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6227
# Clase predicha: CONFIRMED, Probabilidad: 0.5464
# Clase predicha: CONFIRMED, Probabilidad: 0.8988
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8841
# Clase predicha: CONFIRMED, Probabilidad: 0.5503
# Clase predicha: CONFIRMED, Probabilidad: 0.8909
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5043
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8761
# Clase predicha: CONFIRMED, Probabilidad: 0.7005
# Clase predicha: CONFIRMED, Probabilidad: 0.9637
# Clase predicha: CONFIRMED, Probabilidad: 0.6349
# Clase predicha: CONFIRMED, Probabilidad: 0.8905
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9055
# Clase predicha: CONFIRMED, Probabilidad: 0.7708
# Clase predicha: CONFIRMED, Probabilidad: 0.8949
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9371
# Clase predicha: CONFIRMED, Probabilidad: 0.7784
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7685
# Clase predicha: CONFIRMED, Probabilidad: 0.5980
# Clase predicha: CONFIRMED, Probabilidad: 0.7755
# Clase predicha: CONFIRMED, Probabilidad: 0.9861
# Clase predicha: CONFIRMED, Probabilidad: 0.9978
# Clase predicha: CONFIRMED, Probabilidad: 0.9995
# Clase predicha: CONFIRMED, Probabilidad: 0.8151
# Clase predicha: CONFIRMED, Probabilidad: 0.7096
# Clase predicha: CONFIRMED, Probabilidad: 0.7575
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5276
# Clase predicha: CONFIRMED, Probabilidad: 0.5858
# Clase predicha: CONFIRMED, Probabilidad: 0.7200
# Clase predicha: CONFIRMED, Probabilidad: 0.9570
# Clase predicha: CONFIRMED, Probabilidad: 0.9005
# Clase predicha: CONFIRMED, Probabilidad: 0.8036
# Clase predicha: CONFIRMED, Probabilidad: 0.9823
# Clase predicha: CONFIRMED, Probabilidad: 0.9275
# Clase predicha: CONFIRMED, Probabilidad: 0.7332
# Clase predicha: CONFIRMED, Probabilidad: 0.8226
# Clase predicha: CONFIRMED, Probabilidad: 0.8317
# Clase predicha: CONFIRMED, Probabilidad: 0.9745
# Clase predicha: CONFIRMED, Probabilidad: 0.8571
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5295
# Clase predicha: CONFIRMED, Probabilidad: 0.7205
# Clase predicha: CONFIRMED, Probabilidad: 0.9591
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6006
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6040
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6069
# Clase predicha: CONFIRMED, Probabilidad: 0.5186
# Clase predicha: CONFIRMED, Probabilidad: 0.7899
# Clase predicha: CONFIRMED, Probabilidad: 0.9970
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7760
# Clase predicha: CONFIRMED, Probabilidad: 0.6480
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8935
# Clase predicha: CONFIRMED, Probabilidad: 0.9058
# Clase predicha: CONFIRMED, Probabilidad: 0.7256
# Clase predicha: CONFIRMED, Probabilidad: 0.8456
# Clase predicha: CONFIRMED, Probabilidad: 0.9753
# Clase predicha: CONFIRMED, Probabilidad: 0.8047
# Clase predicha: CONFIRMED, Probabilidad: 0.6935
# Clase predicha: CONFIRMED, Probabilidad: 0.9841
# Clase predicha: CONFIRMED, Probabilidad: 0.9983
# Clase predicha: CONFIRMED, Probabilidad: 0.9221
# Clase predicha: CONFIRMED, Probabilidad: 0.9785
# Clase predicha: CONFIRMED, Probabilidad: 0.6693
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7270
# Clase predicha: CONFIRMED, Probabilidad: 0.6559
# Clase predicha: CONFIRMED, Probabilidad: 0.8247
# Clase predicha: CONFIRMED, Probabilidad: 0.8078
# Clase predicha: CONFIRMED, Probabilidad: 0.8523
# Clase predicha: CONFIRMED, Probabilidad: 0.9177
# Clase predicha: CONFIRMED, Probabilidad: 0.5292
# Clase predicha: CONFIRMED, Probabilidad: 0.8719
# Clase predicha: CONFIRMED, Probabilidad: 0.8683
# Clase predicha: CONFIRMED, Probabilidad: 0.9100
# Clase predicha: CONFIRMED, Probabilidad: 0.8885
# Clase predicha: CONFIRMED, Probabilidad: 0.8240
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5700
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8654
# Clase predicha: CONFIRMED, Probabilidad: 0.8884
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9055
# Clase predicha: CONFIRMED, Probabilidad: 0.9016
# Clase predicha: CONFIRMED, Probabilidad: 0.7397
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6580
# Clase predicha: CONFIRMED, Probabilidad: 0.9872
# Clase predicha: CONFIRMED, Probabilidad: 0.6083
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6697
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5006
# Clase predicha: CONFIRMED, Probabilidad: 0.7593
# Clase predicha: CONFIRMED, Probabilidad: 0.7977
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8946
# Clase predicha: CONFIRMED, Probabilidad: 0.7503
# Clase predicha: CONFIRMED, Probabilidad: 0.8678
# Clase predicha: CONFIRMED, Probabilidad: 0.8447
# Clase predicha: CONFIRMED, Probabilidad: 0.7743
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9881
# Clase predicha: CONFIRMED, Probabilidad: 0.8476
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8175
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8031
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8818
# Clase predicha: CONFIRMED, Probabilidad: 0.8475
# Clase predicha: CONFIRMED, Probabilidad: 0.6312
# Clase predicha: CONFIRMED, Probabilidad: 0.5424
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9846
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9853
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7025
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9788
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9813
# Clase predicha: CONFIRMED, Probabilidad: 0.7695
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8320
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9720
# Clase predicha: CONFIRMED, Probabilidad: 0.7284
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9867
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8830
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9681
# Clase predicha: CONFIRMED, Probabilidad: 0.6201
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8505
# Clase predicha: CONFIRMED, Probabilidad: 0.9077
# Clase predicha: CONFIRMED, Probabilidad: 0.8812
# Clase predicha: CONFIRMED, Probabilidad: 0.9639
# Clase predicha: CONFIRMED, Probabilidad: 0.9935
# Clase predicha: CONFIRMED, Probabilidad: 0.8979
# Clase predicha: CONFIRMED, Probabilidad: 0.7519
# Clase predicha: CONFIRMED, Probabilidad: 0.7720
# Clase predicha: CONFIRMED, Probabilidad: 0.5802
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8815
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6923
# Clase predicha: CONFIRMED, Probabilidad: 0.8518
# Clase predicha: CONFIRMED, Probabilidad: 0.5454
# Clase predicha: CONFIRMED, Probabilidad: 0.6805
# Clase predicha: CONFIRMED, Probabilidad: 0.8586
# Clase predicha: CONFIRMED, Probabilidad: 0.6745
# Clase predicha: CONFIRMED, Probabilidad: 0.8363
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8991
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7088
# Clase predicha: CONFIRMED, Probabilidad: 0.7421
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9938
# Clase predicha: CONFIRMED, Probabilidad: 0.7515
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9783
# Clase predicha: CONFIRMED, Probabilidad: 0.8458
# Clase predicha: CONFIRMED, Probabilidad: 0.7702
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7812
# Clase predicha: CONFIRMED, Probabilidad: 0.5805
# Clase predicha: CONFIRMED, Probabilidad: 0.7697
# Clase predicha: CONFIRMED, Probabilidad: 0.5080
# Clase predicha: CONFIRMED, Probabilidad: 0.8753
# Clase predicha: CONFIRMED, Probabilidad: 0.8691
# Clase predicha: CONFIRMED, Probabilidad: 0.9216
# Clase predicha: CONFIRMED, Probabilidad: 0.9884
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6271
# Clase predicha: CONFIRMED, Probabilidad: 0.6133
# Clase predicha: CONFIRMED, Probabilidad: 0.9799
# Clase predicha: CONFIRMED, Probabilidad: 0.8683
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5403
# Clase predicha: CONFIRMED, Probabilidad: 0.8719
# Clase predicha: CONFIRMED, Probabilidad: 0.9282
# Clase predicha: CONFIRMED, Probabilidad: 0.8151
# Clase predicha: CONFIRMED, Probabilidad: 0.9531
# Clase predicha: CONFIRMED, Probabilidad: 0.8760
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6393
# Clase predicha: CONFIRMED, Probabilidad: 0.7444
# Clase predicha: CONFIRMED, Probabilidad: 0.8250
# Clase predicha: CONFIRMED, Probabilidad: 0.8498
# Clase predicha: CONFIRMED, Probabilidad: 0.7039
# Clase predicha: CONFIRMED, Probabilidad: 0.5723
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6911
# Clase predicha: CONFIRMED, Probabilidad: 0.8760
# Clase predicha: CONFIRMED, Probabilidad: 0.9722
# Clase predicha: CONFIRMED, Probabilidad: 0.9061
# Clase predicha: CONFIRMED, Probabilidad: 0.9868
# Clase predicha: CONFIRMED, Probabilidad: 0.9982
# Clase predicha: CONFIRMED, Probabilidad: 0.9998
# Clase predicha: CONFIRMED, Probabilidad: 1.0000
# Clase predicha: CONFIRMED, Probabilidad: 0.9715
# Clase predicha: CONFIRMED, Probabilidad: 0.8317
# Clase predicha: CONFIRMED, Probabilidad: 0.9430
# Clase predicha: CONFIRMED, Probabilidad: 0.7788
# Clase predicha: CONFIRMED, Probabilidad: 0.7424
# Clase predicha: CONFIRMED, Probabilidad: 0.8642
# Clase predicha: CONFIRMED, Probabilidad: 0.9241
# Clase predicha: CONFIRMED, Probabilidad: 0.7999
# Clase predicha: CONFIRMED, Probabilidad: 0.8392
# Clase predicha: CONFIRMED, Probabilidad: 0.9776
# Clase predicha: CONFIRMED, Probabilidad: 0.8976
# Clase predicha: CONFIRMED, Probabilidad: 0.7250
# Clase predicha: CONFIRMED, Probabilidad: 0.9037
# Clase predicha: CONFIRMED, Probabilidad: 0.6301
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8167
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6329
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8232
# Clase predicha: CONFIRMED, Probabilidad: 0.7226
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6688
# Clase predicha: CONFIRMED, Probabilidad: 0.7226
# Clase predicha: CONFIRMED, Probabilidad: 0.7356
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7238
# Clase predicha: CONFIRMED, Probabilidad: 0.5299
# Clase predicha: CONFIRMED, Probabilidad: 0.8061
# Clase predicha: CONFIRMED, Probabilidad: 0.8176
# Clase predicha: CONFIRMED, Probabilidad: 0.8435
# Clase predicha: CONFIRMED, Probabilidad: 0.7360
# Clase predicha: CONFIRMED, Probabilidad: 0.7941
# Clase predicha: CONFIRMED, Probabilidad: 0.7136
# Clase predicha: CONFIRMED, Probabilidad: 0.8160
# Clase predicha: CONFIRMED, Probabilidad: 0.6840
# Clase predicha: CONFIRMED, Probabilidad: 0.7356
# Clase predicha: CONFIRMED, Probabilidad: 0.8629
# Clase predicha: CONFIRMED, Probabilidad: 0.6320
# Clase predicha: CONFIRMED, Probabilidad: 0.6103
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9371
# Clase predicha: CONFIRMED, Probabilidad: 0.5035
# Clase predicha: CONFIRMED, Probabilidad: 0.8376
# Clase predicha: CONFIRMED, Probabilidad: 0.8217
# Clase predicha: CONFIRMED, Probabilidad: 0.8525
# Clase predicha: CONFIRMED, Probabilidad: 0.7056
# Clase predicha: CONFIRMED, Probabilidad: 0.5561
# Clase predicha: CONFIRMED, Probabilidad: 0.7469
# Clase predicha: CONFIRMED, Probabilidad: 0.8212
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5289
# Clase predicha: CONFIRMED, Probabilidad: 0.7245
# Clase predicha: CONFIRMED, Probabilidad: 0.7827
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9304
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7585
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7452
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7934
# Clase predicha: CONFIRMED, Probabilidad: 0.6877
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8817
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7234
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5702
# Clase predicha: CONFIRMED, Probabilidad: 0.7002
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9480
# Clase predicha: CONFIRMED, Probabilidad: 0.8043
# Clase predicha: CONFIRMED, Probabilidad: 0.6399
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7743
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7984
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9287
# Clase predicha: CONFIRMED, Probabilidad: 0.7847
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9206
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7485
# Clase predicha: CONFIRMED, Probabilidad: 0.9717
# Clase predicha: CONFIRMED, Probabilidad: 0.9917
# Clase predicha: CONFIRMED, Probabilidad: 0.8384
# Clase predicha: CONFIRMED, Probabilidad: 0.9801
# Clase predicha: CONFIRMED, Probabilidad: 0.6258
# Clase predicha: CONFIRMED, Probabilidad: 0.9095
# Clase predicha: CONFIRMED, Probabilidad: 0.9437
# Clase predicha: CONFIRMED, Probabilidad: 0.8550
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9466
# Clase predicha: CONFIRMED, Probabilidad: 0.8734
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5366
# Clase predicha: CONFIRMED, Probabilidad: 0.8837
# Clase predicha: CONFIRMED, Probabilidad: 0.8251
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7029
# Clase predicha: CONFIRMED, Probabilidad: 0.8354
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7122
# Clase predicha: CONFIRMED, Probabilidad: 0.9375
# Clase predicha: CONFIRMED, Probabilidad: 0.6869
# Clase predicha: CONFIRMED, Probabilidad: 0.8766
# Clase predicha: CONFIRMED, Probabilidad: 0.7983
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6561
# Clase predicha: CONFIRMED, Probabilidad: 0.9643
# Clase predicha: CONFIRMED, Probabilidad: 0.8542
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5018
# Clase predicha: CONFIRMED, Probabilidad: 0.8864
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9370
# Clase predicha: CONFIRMED, Probabilidad: 0.5371
# Clase predicha: CONFIRMED, Probabilidad: 0.8088
# Clase predicha: CONFIRMED, Probabilidad: 0.8030
# Clase predicha: CONFIRMED, Probabilidad: 0.5554
# Clase predicha: CONFIRMED, Probabilidad: 0.6776
# Clase predicha: CONFIRMED, Probabilidad: 0.6988
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7806
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9681
# Clase predicha: CONFIRMED, Probabilidad: 0.6794
# Clase predicha: CONFIRMED, Probabilidad: 0.8011
# Clase predicha: CONFIRMED, Probabilidad: 0.9729
# Clase predicha: CONFIRMED, Probabilidad: 0.9943
# Clase predicha: CONFIRMED, Probabilidad: 0.7010
# Clase predicha: CONFIRMED, Probabilidad: 0.8638
# Clase predicha: CONFIRMED, Probabilidad: 0.7435
# Clase predicha: CONFIRMED, Probabilidad: 0.7021
# Clase predicha: CONFIRMED, Probabilidad: 0.8026
# Clase predicha: CONFIRMED, Probabilidad: 0.8237
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7817
# Clase predicha: CONFIRMED, Probabilidad: 0.6417
# Clase predicha: CONFIRMED, Probabilidad: 0.5790
# Clase predicha: CONFIRMED, Probabilidad: 0.8923
# Clase predicha: CONFIRMED, Probabilidad: 0.8609
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9447
# Clase predicha: CONFIRMED, Probabilidad: 0.5282
# Clase predicha: CONFIRMED, Probabilidad: 0.8036
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8518
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9069
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9373
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7804
# Clase predicha: CONFIRMED, Probabilidad: 0.6554
# Clase predicha: CONFIRMED, Probabilidad: 0.5990
# Clase predicha: CONFIRMED, Probabilidad: 0.6806
# Clase predicha: CONFIRMED, Probabilidad: 0.5601
# Clase predicha: CONFIRMED, Probabilidad: 0.6857
# Clase predicha: CONFIRMED, Probabilidad: 0.7712
# Clase predicha: CONFIRMED, Probabilidad: 0.7522
# Clase predicha: CONFIRMED, Probabilidad: 0.5855
# Clase predicha: CONFIRMED, Probabilidad: 0.8817
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5179
# Clase predicha: CONFIRMED, Probabilidad: 0.7146
# Clase predicha: CONFIRMED, Probabilidad: 0.8202
# Clase predicha: CONFIRMED, Probabilidad: 0.6058
# Clase predicha: CONFIRMED, Probabilidad: 0.6264
# Clase predicha: CONFIRMED, Probabilidad: 0.7875
# Clase predicha: CONFIRMED, Probabilidad: 0.8128
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9551
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5141
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6350
# Clase predicha: CONFIRMED, Probabilidad: 0.5341
# Clase predicha: CONFIRMED, Probabilidad: 0.9588
# Clase predicha: CONFIRMED, Probabilidad: 0.7703
# Clase predicha: CONFIRMED, Probabilidad: 0.5225
# Clase predicha: CONFIRMED, Probabilidad: 0.8118
# Clase predicha: CONFIRMED, Probabilidad: 0.6908
# Clase predicha: CONFIRMED, Probabilidad: 0.7012
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8140
# Clase predicha: CONFIRMED, Probabilidad: 0.5287
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5762
# Clase predicha: CONFIRMED, Probabilidad: 0.8169
# Clase predicha: CONFIRMED, Probabilidad: 0.5060
# Clase predicha: CONFIRMED, Probabilidad: 0.5091
# Clase predicha: CONFIRMED, Probabilidad: 0.7301
# Clase predicha: CONFIRMED, Probabilidad: 0.7020
# Clase predicha: CONFIRMED, Probabilidad: 0.6756
# Clase predicha: CONFIRMED, Probabilidad: 0.8152
# Clase predicha: CONFIRMED, Probabilidad: 0.5863
# Clase predicha: CONFIRMED, Probabilidad: 0.7682
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9413
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9589
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6782
# Clase predicha: CONFIRMED, Probabilidad: 0.6990
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6430
# Clase predicha: CONFIRMED, Probabilidad: 0.8542
# Clase predicha: CONFIRMED, Probabilidad: 0.6727
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7183
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8158
# Clase predicha: CONFIRMED, Probabilidad: 0.7457
# Clase predicha: CONFIRMED, Probabilidad: 0.6505
# Clase predicha: CONFIRMED, Probabilidad: 0.7467
# Clase predicha: CONFIRMED, Probabilidad: 0.7052
# Clase predicha: CONFIRMED, Probabilidad: 0.7502
# Clase predicha: CONFIRMED, Probabilidad: 0.6446
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5261
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7203
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6707
# Clase predicha: CONFIRMED, Probabilidad: 0.8066
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8558
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9585
# Clase predicha: CONFIRMED, Probabilidad: 0.6066
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6464
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7079
# Clase predicha: CONFIRMED, Probabilidad: 0.6320
# Clase predicha: CONFIRMED, Probabilidad: 0.6055
# Clase predicha: CONFIRMED, Probabilidad: 0.6682
# Clase predicha: CONFIRMED, Probabilidad: 0.7168
# Clase predicha: CONFIRMED, Probabilidad: 0.7105
# Clase predicha: CONFIRMED, Probabilidad: 0.8358
# Clase predicha: CONFIRMED, Probabilidad: 0.7440
# Clase predicha: CONFIRMED, Probabilidad: 0.7857
# Clase predicha: CONFIRMED, Probabilidad: 0.7401
# Clase predicha: CONFIRMED, Probabilidad: 0.9076
# Clase predicha: CONFIRMED, Probabilidad: 0.8355
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7503
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6723
# Clase predicha: CONFIRMED, Probabilidad: 0.6409
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7302
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8030
# Clase predicha: CONFIRMED, Probabilidad: 0.7053
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9181
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8365
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5299
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6364
# Clase predicha: CONFIRMED, Probabilidad: 0.5083
# Clase predicha: CONFIRMED, Probabilidad: 0.6549
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8805
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7719
# Clase predicha: CONFIRMED, Probabilidad: 0.5405
# Clase predicha: CONFIRMED, Probabilidad: 0.8211
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9319
# Clase predicha: CONFIRMED, Probabilidad: 0.8186
# Clase predicha: CONFIRMED, Probabilidad: 0.7983
# Clase predicha: CONFIRMED, Probabilidad: 0.8582
# Clase predicha: CONFIRMED, Probabilidad: 0.8022
# Clase predicha: CONFIRMED, Probabilidad: 0.7457
# Clase predicha: CONFIRMED, Probabilidad: 0.7307
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9412
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9424
# Clase predicha: CONFIRMED, Probabilidad: 0.8804
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9740
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9402
# Clase predicha: CONFIRMED, Probabilidad: 0.6436
# Clase predicha: CONFIRMED, Probabilidad: 0.8013
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8232
# Clase predicha: CONFIRMED, Probabilidad: 0.7208
# Clase predicha: CONFIRMED, Probabilidad: 0.7191
# Clase predicha: CONFIRMED, Probabilidad: 0.6828
# Clase predicha: CONFIRMED, Probabilidad: 0.8409
# Clase predicha: CONFIRMED, Probabilidad: 0.8481
# Clase predicha: CONFIRMED, Probabilidad: 0.8369
# Clase predicha: CONFIRMED, Probabilidad: 0.8594
# Clase predicha: CONFIRMED, Probabilidad: 0.6169
# Clase predicha: CONFIRMED, Probabilidad: 0.7923
# Clase predicha: CONFIRMED, Probabilidad: 0.7969
# Clase predicha: CONFIRMED, Probabilidad: 0.7519
# Clase predicha: CONFIRMED, Probabilidad: 0.8145
# Clase predicha: CONFIRMED, Probabilidad: 0.7211
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5004
# Clase predicha: CONFIRMED, Probabilidad: 0.9120
# Clase predicha: CONFIRMED, Probabilidad: 0.8773
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8967
# Clase predicha: CONFIRMED, Probabilidad: 0.8524
# Clase predicha: CONFIRMED, Probabilidad: 0.8475
# Clase predicha: CONFIRMED, Probabilidad: 0.8106
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7239
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8714
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9601
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9556
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9964
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8615
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7182
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8838
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6672
# Clase predicha: CONFIRMED, Probabilidad: 0.8188
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5284
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5166
# Clase predicha: CONFIRMED, Probabilidad: 0.8150
# Clase predicha: CONFIRMED, Probabilidad: 0.7330
# Clase predicha: CONFIRMED, Probabilidad: 0.7382
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8038
# Clase predicha: CONFIRMED, Probabilidad: 0.7706
# Clase predicha: CONFIRMED, Probabilidad: 0.7186
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5531
# Clase predicha: CONFIRMED, Probabilidad: 0.7764
# Clase predicha: CONFIRMED, Probabilidad: 0.8218
# Clase predicha: CONFIRMED, Probabilidad: 0.8521
# Clase predicha: CONFIRMED, Probabilidad: 0.7179
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9084
# Clase predicha: CONFIRMED, Probabilidad: 0.8039
# Clase predicha: CONFIRMED, Probabilidad: 0.7103
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6654
# Clase predicha: CONFIRMED, Probabilidad: 0.6930
# Clase predicha: CONFIRMED, Probabilidad: 0.7490
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5260
# Clase predicha: CONFIRMED, Probabilidad: 0.5916
# Clase predicha: CONFIRMED, Probabilidad: 0.6809
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9556
# Clase predicha: CONFIRMED, Probabilidad: 0.6934
# Clase predicha: CONFIRMED, Probabilidad: 0.6060
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5861
# Clase predicha: CONFIRMED, Probabilidad: 0.7995
# Clase predicha: CONFIRMED, Probabilidad: 0.5422
# Clase predicha: CONFIRMED, Probabilidad: 0.7510
# Clase predicha: CONFIRMED, Probabilidad: 0.8023
# Clase predicha: CONFIRMED, Probabilidad: 0.7135
# Clase predicha: CONFIRMED, Probabilidad: 0.7826
# Clase predicha: CONFIRMED, Probabilidad: 0.5378
# Clase predicha: CONFIRMED, Probabilidad: 0.7895
# Clase predicha: CONFIRMED, Probabilidad: 0.8177
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5470
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9496
# Clase predicha: CONFIRMED, Probabilidad: 0.7056
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5126
# Clase predicha: CONFIRMED, Probabilidad: 0.8319
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7906
# Clase predicha: CONFIRMED, Probabilidad: 0.8452
# Clase predicha: CONFIRMED, Probabilidad: 0.8736
# Clase predicha: CONFIRMED, Probabilidad: 0.7147
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5307
# Clase predicha: CONFIRMED, Probabilidad: 0.7963
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9400
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5519
# Clase predicha: CONFIRMED, Probabilidad: 0.7958
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7960
# Clase predicha: CONFIRMED, Probabilidad: 0.8333
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8095
# Clase predicha: CONFIRMED, Probabilidad: 0.6518
# Clase predicha: CONFIRMED, Probabilidad: 0.8282
# Clase predicha: CONFIRMED, Probabilidad: 0.7976
# Clase predicha: CONFIRMED, Probabilidad: 0.7077
# Clase predicha: CONFIRMED, Probabilidad: 0.8615
# Clase predicha: CONFIRMED, Probabilidad: 0.8205
# Clase predicha: CONFIRMED, Probabilidad: 0.8399
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8587
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5186
# Clase predicha: CONFIRMED, Probabilidad: 0.8704
# Clase predicha: CONFIRMED, Probabilidad: 0.7649
# Clase predicha: CONFIRMED, Probabilidad: 0.7595
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8632
# Clase predicha: CONFIRMED, Probabilidad: 0.7342
# Clase predicha: CONFIRMED, Probabilidad: 0.7968
# Clase predicha: CONFIRMED, Probabilidad: 0.8561
# Clase predicha: CONFIRMED, Probabilidad: 0.7592
# Clase predicha: CONFIRMED, Probabilidad: 0.7846
# Clase predicha: CONFIRMED, Probabilidad: 0.8663
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8627
# Clase predicha: CONFIRMED, Probabilidad: 0.8038
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9320
# Clase predicha: CONFIRMED, Probabilidad: 0.7918
# Clase predicha: CONFIRMED, Probabilidad: 0.5672
# Clase predicha: CONFIRMED, Probabilidad: 0.6718
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9780
# Clase predicha: CONFIRMED, Probabilidad: 0.8274
# Clase predicha: CONFIRMED, Probabilidad: 0.8267
# Clase predicha: CONFIRMED, Probabilidad: 0.5876
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8871
# Clase predicha: CONFIRMED, Probabilidad: 0.8575
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5028
# Clase predicha: CONFIRMED, Probabilidad: 0.7326
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8496
# Clase predicha: CONFIRMED, Probabilidad: 0.6026
# Clase predicha: CONFIRMED, Probabilidad: 0.8263
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8949
# Clase predicha: CONFIRMED, Probabilidad: 0.8190
# Clase predicha: CONFIRMED, Probabilidad: 0.5619
# Clase predicha: CONFIRMED, Probabilidad: 0.8131
# Clase predicha: CONFIRMED, Probabilidad: 0.8470
# Clase predicha: CONFIRMED, Probabilidad: 0.8028
# Clase predicha: CONFIRMED, Probabilidad: 0.6698
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5628
# Clase predicha: CONFIRMED, Probabilidad: 0.8211
# Clase predicha: CONFIRMED, Probabilidad: 0.7568
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8942
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9571
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9901
# Clase predicha: CONFIRMED, Probabilidad: 0.8526
# Clase predicha: CONFIRMED, Probabilidad: 0.5437
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7326
# Clase predicha: CONFIRMED, Probabilidad: 0.8242
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6159
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9637
# Clase predicha: CONFIRMED, Probabilidad: 0.7743
# Clase predicha: CONFIRMED, Probabilidad: 0.8056
# Clase predicha: CONFIRMED, Probabilidad: 0.7383
# Clase predicha: CONFIRMED, Probabilidad: 0.7589
# Clase predicha: CONFIRMED, Probabilidad: 0.7395
# Clase predicha: CONFIRMED, Probabilidad: 0.6884
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8469
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9370
# Clase predicha: CONFIRMED, Probabilidad: 0.8111
# Clase predicha: CONFIRMED, Probabilidad: 0.8284
# Clase predicha: CONFIRMED, Probabilidad: 0.8580
# Clase predicha: CONFIRMED, Probabilidad: 0.7083
# Clase predicha: CONFIRMED, Probabilidad: 0.6776
# Clase predicha: CONFIRMED, Probabilidad: 0.6795
# Clase predicha: CONFIRMED, Probabilidad: 0.8127
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8249
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6870
# Clase predicha: CONFIRMED, Probabilidad: 0.5831
# Clase predicha: CONFIRMED, Probabilidad: 0.5474
# Clase predicha: CONFIRMED, Probabilidad: 0.8979
# Clase predicha: CONFIRMED, Probabilidad: 0.6378
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7903
# Clase predicha: CONFIRMED, Probabilidad: 0.6658
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8756
# Clase predicha: CONFIRMED, Probabilidad: 0.8009
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7341
# Clase predicha: CONFIRMED, Probabilidad: 0.8083
# Clase predicha: CONFIRMED, Probabilidad: 0.8112
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9704
# Clase predicha: CONFIRMED, Probabilidad: 0.5928
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8931
# Clase predicha: CONFIRMED, Probabilidad: 0.8299
# Clase predicha: CONFIRMED, Probabilidad: 0.5085
# Clase predicha: CONFIRMED, Probabilidad: 0.7965
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9634
# Clase predicha: CONFIRMED, Probabilidad: 0.7852
# Clase predicha: CONFIRMED, Probabilidad: 0.7943
# Clase predicha: CONFIRMED, Probabilidad: 0.7222
# Clase predicha: CONFIRMED, Probabilidad: 0.7174
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9429
# Clase predicha: CONFIRMED, Probabilidad: 0.7486
# Clase predicha: CONFIRMED, Probabilidad: 0.7440
# Clase predicha: CONFIRMED, Probabilidad: 0.8026
# Clase predicha: CONFIRMED, Probabilidad: 0.8799
# Clase predicha: CONFIRMED, Probabilidad: 0.5860
# Clase predicha: CONFIRMED, Probabilidad: 0.5235
# Clase predicha: CONFIRMED, Probabilidad: 0.7098
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9765
# Clase predicha: CONFIRMED, Probabilidad: 0.5851
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9910
# Clase predicha: CONFIRMED, Probabilidad: 0.6002
# Clase predicha: CONFIRMED, Probabilidad: 0.8263
# Clase predicha: CONFIRMED, Probabilidad: 0.7212
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9545
# Clase predicha: CONFIRMED, Probabilidad: 0.8894
# Clase predicha: CONFIRMED, Probabilidad: 0.8657
# Clase predicha: CONFIRMED, Probabilidad: 0.8449
# Clase predicha: CONFIRMED, Probabilidad: 0.7081
# Clase predicha: CONFIRMED, Probabilidad: 0.5635
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9587
# Clase predicha: CONFIRMED, Probabilidad: 0.7536
# Clase predicha: CONFIRMED, Probabilidad: 0.8193
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8820
# Clase predicha: CONFIRMED, Probabilidad: 0.6110
# Clase predicha: CONFIRMED, Probabilidad: 0.6977
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9472
# Clase predicha: CONFIRMED, Probabilidad: 0.5109
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9847
# Clase predicha: CONFIRMED, Probabilidad: 0.8052
# Clase predicha: CONFIRMED, Probabilidad: 0.8036
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5352
# Clase predicha: CONFIRMED, Probabilidad: 0.5695
# Clase predicha: CONFIRMED, Probabilidad: 0.8184
# Clase predicha: CONFIRMED, Probabilidad: 0.7184
# Clase predicha: CONFIRMED, Probabilidad: 0.8289
# Clase predicha: CONFIRMED, Probabilidad: 0.8480
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9790
# Clase predicha: CONFIRMED, Probabilidad: 0.7600
# Clase predicha: CONFIRMED, Probabilidad: 0.6113
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6212
# Clase predicha: CONFIRMED, Probabilidad: 0.6900
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6641
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5138
# Clase predicha: CONFIRMED, Probabilidad: 0.7822
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6473
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5485
# Clase predicha: CONFIRMED, Probabilidad: 0.8170
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8367
# Clase predicha: CONFIRMED, Probabilidad: 0.6921
# Clase predicha: CONFIRMED, Probabilidad: 0.8311
# Clase predicha: CONFIRMED, Probabilidad: 0.7936
# Clase predicha: CONFIRMED, Probabilidad: 0.8951
# Clase predicha: CONFIRMED, Probabilidad: 0.6898
# Clase predicha: CONFIRMED, Probabilidad: 0.7396
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8959
# Clase predicha: CONFIRMED, Probabilidad: 0.7710
# Clase predicha: CONFIRMED, Probabilidad: 0.7511
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9382
# Clase predicha: CONFIRMED, Probabilidad: 0.5221
# Clase predicha: CONFIRMED, Probabilidad: 0.5649
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5485
# Clase predicha: CONFIRMED, Probabilidad: 0.6910
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8264
# Clase predicha: CONFIRMED, Probabilidad: 0.8078
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5715
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8984
# Clase predicha: CONFIRMED, Probabilidad: 0.8247
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7913
# Clase predicha: CONFIRMED, Probabilidad: 0.7730
# Clase predicha: CONFIRMED, Probabilidad: 0.8471
# Clase predicha: CONFIRMED, Probabilidad: 0.7429
# Clase predicha: CONFIRMED, Probabilidad: 0.7327
# Clase predicha: CONFIRMED, Probabilidad: 0.5259
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6812
# Clase predicha: CONFIRMED, Probabilidad: 0.8314
# Clase predicha: CONFIRMED, Probabilidad: 0.7659
# Clase predicha: CONFIRMED, Probabilidad: 0.6142
# Clase predicha: CONFIRMED, Probabilidad: 0.8008
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9800
# Clase predicha: CONFIRMED, Probabilidad: 0.7547
# Clase predicha: CONFIRMED, Probabilidad: 0.6764
# Clase predicha: CONFIRMED, Probabilidad: 0.8926
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9292
# Clase predicha: CONFIRMED, Probabilidad: 0.5398
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6519
# Clase predicha: CONFIRMED, Probabilidad: 0.5757
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9472
# Clase predicha: CONFIRMED, Probabilidad: 0.7018
# Clase predicha: CONFIRMED, Probabilidad: 0.9162
# Clase predicha: CONFIRMED, Probabilidad: 0.6139
# Clase predicha: CONFIRMED, Probabilidad: 0.7975
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9726
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6360
# Clase predicha: CONFIRMED, Probabilidad: 0.7083
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5057
# Clase predicha: CONFIRMED, Probabilidad: 0.7118
# Clase predicha: CONFIRMED, Probabilidad: 0.7001
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5982
# Clase predicha: CONFIRMED, Probabilidad: 0.6092
# Clase predicha: CONFIRMED, Probabilidad: 0.5132
# Clase predicha: CONFIRMED, Probabilidad: 0.7729
# Clase predicha: CONFIRMED, Probabilidad: 0.8771
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7566
# Clase predicha: CONFIRMED, Probabilidad: 0.7633
# Clase predicha: CONFIRMED, Probabilidad: 0.7499
# Clase predicha: CONFIRMED, Probabilidad: 0.6884
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8288
# Clase predicha: CONFIRMED, Probabilidad: 0.6102
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9543
# Clase predicha: CONFIRMED, Probabilidad: 0.5916
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9439
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5154
# Clase predicha: CONFIRMED, Probabilidad: 0.7278
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9379
# Clase predicha: CONFIRMED, Probabilidad: 0.6766
# Clase predicha: CONFIRMED, Probabilidad: 0.5898
# Clase predicha: CONFIRMED, Probabilidad: 0.6185
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9260
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5737
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6685
# Clase predicha: CONFIRMED, Probabilidad: 0.6212
# Clase predicha: CONFIRMED, Probabilidad: 0.7672
# Clase predicha: CONFIRMED, Probabilidad: 0.8907
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6558
# Clase predicha: CONFIRMED, Probabilidad: 0.6379
# Clase predicha: CONFIRMED, Probabilidad: 0.8461
# Clase predicha: CONFIRMED, Probabilidad: 0.6386
# Clase predicha: CONFIRMED, Probabilidad: 0.8334
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5726
# Clase predicha: CONFIRMED, Probabilidad: 0.7026
# Clase predicha: CONFIRMED, Probabilidad: 0.7018
# Clase predicha: CONFIRMED, Probabilidad: 0.6207
# Clase predicha: CONFIRMED, Probabilidad: 0.6763
# Clase predicha: CONFIRMED, Probabilidad: 0.7765
# Clase predicha: CONFIRMED, Probabilidad: 0.7709
# Clase predicha: CONFIRMED, Probabilidad: 0.6915
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9160
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5613
# Clase predicha: CONFIRMED, Probabilidad: 0.6487
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6493
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8251
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6248
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9053
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8844
# Clase predicha: CONFIRMED, Probabilidad: 0.7616
# Clase predicha: CONFIRMED, Probabilidad: 0.7049
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9043
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6666
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8993
# Clase predicha: CONFIRMED, Probabilidad: 0.8664
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9408
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5395
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8977
# Clase predicha: CONFIRMED, Probabilidad: 0.7391
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9762
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5150
# Clase predicha: CONFIRMED, Probabilidad: 0.8266
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8774
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5198
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9635
# Clase predicha: CONFIRMED, Probabilidad: 0.7292
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6829
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6922
# Clase predicha: CONFIRMED, Probabilidad: 0.8628
# Clase predicha: CONFIRMED, Probabilidad: 0.7129
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5416
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6187
# Clase predicha: CONFIRMED, Probabilidad: 0.5483
# Clase predicha: CONFIRMED, Probabilidad: 0.6502
# Clase predicha: CONFIRMED, Probabilidad: 0.6809
# Clase predicha: CONFIRMED, Probabilidad: 0.6822
# Clase predicha: CONFIRMED, Probabilidad: 0.7787
# Clase predicha: CONFIRMED, Probabilidad: 0.7126
# Clase predicha: CONFIRMED, Probabilidad: 0.9327
# Clase predicha: CONFIRMED, Probabilidad: 0.7399
# Clase predicha: CONFIRMED, Probabilidad: 0.8369
# Clase predicha: CONFIRMED, Probabilidad: 0.6410
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7434
# Clase predicha: CONFIRMED, Probabilidad: 0.7300
# Clase predicha: CONFIRMED, Probabilidad: 0.8094
# Clase predicha: CONFIRMED, Probabilidad: 0.7789
# Clase predicha: CONFIRMED, Probabilidad: 0.7371
# Clase predicha: CONFIRMED, Probabilidad: 0.7162
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7253
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8751
# Clase predicha: CONFIRMED, Probabilidad: 0.7240
# Clase predicha: CONFIRMED, Probabilidad: 0.6829
# Clase predicha: CONFIRMED, Probabilidad: 0.7932
# Clase predicha: CONFIRMED, Probabilidad: 0.6458
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7225
# Clase predicha: CONFIRMED, Probabilidad: 0.8397
# Clase predicha: CONFIRMED, Probabilidad: 0.7001
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9115
# Clase predicha: CONFIRMED, Probabilidad: 0.5692
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9805
# Clase predicha: CONFIRMED, Probabilidad: 0.6114
# Clase predicha: CONFIRMED, Probabilidad: 0.7055
# Clase predicha: CONFIRMED, Probabilidad: 0.6102
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6825
# Clase predicha: CONFIRMED, Probabilidad: 0.8306
# Clase predicha: CONFIRMED, Probabilidad: 0.5944
# Clase predicha: CONFIRMED, Probabilidad: 0.6893
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5455
# Clase predicha: CONFIRMED, Probabilidad: 0.7234
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5562
# Clase predicha: CONFIRMED, Probabilidad: 0.7306
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6613
# Clase predicha: CONFIRMED, Probabilidad: 0.5496
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5117
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9302
# Clase predicha: CONFIRMED, Probabilidad: 0.6407
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9086
# Clase predicha: CONFIRMED, Probabilidad: 0.6419
# Clase predicha: CONFIRMED, Probabilidad: 0.5819
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6993
# Clase predicha: CONFIRMED, Probabilidad: 0.5466
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7718
# Clase predicha: CONFIRMED, Probabilidad: 0.6922
# Clase predicha: CONFIRMED, Probabilidad: 0.7310
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5026
# Clase predicha: CONFIRMED, Probabilidad: 0.8778
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5590
# Clase predicha: CONFIRMED, Probabilidad: 0.7534
# Clase predicha: CONFIRMED, Probabilidad: 0.7785
# Clase predicha: CONFIRMED, Probabilidad: 0.7877
# Clase predicha: CONFIRMED, Probabilidad: 0.9156
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7391
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5568
# Clase predicha: CONFIRMED, Probabilidad: 0.5453
# Clase predicha: CONFIRMED, Probabilidad: 0.6327
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6927
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7353
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9791
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8814
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8898
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8940
# Clase predicha: CONFIRMED, Probabilidad: 0.5953
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5749
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9850
# Clase predicha: CONFIRMED, Probabilidad: 0.7680
# Clase predicha: CONFIRMED, Probabilidad: 0.7003
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8491
# ...
# Clase predicha: CONFIRMED, Probabilidad: 0.7494
# Clase predicha: CONFIRMED, Probabilidad: 0.7472
# Clase predicha: CONFIRMED, Probabilidad: 0.5559
# Clase predicha: CONFIRMED, Probabilidad: 0.6980
# Clase predicha: CONFIRMED, Probabilidad: 0.5456
# Clase predicha: CONFIRMED, Probabilidad: 0.6223
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6655
# Clase predicha: CONFIRMED, Probabilidad: 0.6077
# Clase predicha: CONFIRMED, Probabilidad: 0.7395
# Clase predicha: CONFIRMED, Probabilidad: 0.5252
# Clase predicha: CONFIRMED, Probabilidad: 0.5114
# Clase predicha: CONFIRMED, Probabilidad: 0.5113
# Clase predicha: CONFIRMED, Probabilidad: 0.6926
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5544
# Clase predicha: CONFIRMED, Probabilidad: 0.6800
# Clase predicha: CONFIRMED, Probabilidad: 0.7068
# Clase predicha: CONFIRMED, Probabilidad: 0.7622
# Clase predicha: CONFIRMED, Probabilidad: 0.6522
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6833
# Clase predicha: CONFIRMED, Probabilidad: 0.8049
# Clase predicha: CONFIRMED, Probabilidad: 0.6957
# Clase predicha: CONFIRMED, Probabilidad: 0.7259
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7320
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8306
# Clase predicha: CONFIRMED, Probabilidad: 0.7085
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6431
# Clase predicha: CONFIRMED, Probabilidad: 0.5497
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6578
# Clase predicha: CONFIRMED, Probabilidad: 0.6473
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9271
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9262
# Clase predicha: CONFIRMED, Probabilidad: 0.6126
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8223
# Clase predicha: CONFIRMED, Probabilidad: 0.5466
# Clase predicha: CONFIRMED, Probabilidad: 0.7738
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5791
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5438
# Clase predicha: CONFIRMED, Probabilidad: 0.7097
# Clase predicha: CONFIRMED, Probabilidad: 0.6383
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5050
# Clase predicha: CONFIRMED, Probabilidad: 0.5624
# Clase predicha: CONFIRMED, Probabilidad: 0.7498
# Clase predicha: CONFIRMED, Probabilidad: 0.6763
# Clase predicha: CONFIRMED, Probabilidad: 0.7377
# Clase predicha: CONFIRMED, Probabilidad: 0.8876
# Clase predicha: CONFIRMED, Probabilidad: 0.9711
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7750
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6036
# Clase predicha: CONFIRMED, Probabilidad: 0.6875
# Clase predicha: CONFIRMED, Probabilidad: 0.5303
# Clase predicha: CONFIRMED, Probabilidad: 0.8184
# Clase predicha: CONFIRMED, Probabilidad: 0.7374
# Clase predicha: CONFIRMED, Probabilidad: 0.5617
# Clase predicha: CONFIRMED, Probabilidad: 0.7068
# Clase predicha: CONFIRMED, Probabilidad: 0.7498
# Clase predicha: CONFIRMED, Probabilidad: 0.7190
# Clase predicha: CONFIRMED, Probabilidad: 0.7303
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8473
# Clase predicha: CONFIRMED, Probabilidad: 0.7277
# Clase predicha: CONFIRMED, Probabilidad: 0.6297
# Clase predicha: CONFIRMED, Probabilidad: 0.7131
# Clase predicha: CONFIRMED, Probabilidad: 0.6056
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6668
# Clase predicha: CONFIRMED, Probabilidad: 0.6830
# Clase predicha: CONFIRMED, Probabilidad: 0.6424
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5221
# Clase predicha: CONFIRMED, Probabilidad: 0.5814
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6464
# Clase predicha: CONFIRMED, Probabilidad: 0.5261
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5166
# Clase predicha: CONFIRMED, Probabilidad: 0.5477
# Clase predicha: CONFIRMED, Probabilidad: 0.7624
# Clase predicha: CONFIRMED, Probabilidad: 0.7302
# Clase predicha: CONFIRMED, Probabilidad: 0.6266
# Clase predicha: CONFIRMED, Probabilidad: 0.7609
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5651
# Clase predicha: CONFIRMED, Probabilidad: 0.6778
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5466
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7083
# Clase predicha: CONFIRMED, Probabilidad: 0.7716
# Clase predicha: CONFIRMED, Probabilidad: 0.6642
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8328
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5494
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9454
# Clase predicha: CONFIRMED, Probabilidad: 0.7083
# Clase predicha: CONFIRMED, Probabilidad: 0.7855
# Clase predicha: CONFIRMED, Probabilidad: 0.7432
# Clase predicha: CONFIRMED, Probabilidad: 0.6454
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6170
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6408
# Clase predicha: CONFIRMED, Probabilidad: 0.5402
# Clase predicha: CONFIRMED, Probabilidad: 0.7602
# Clase predicha: CONFIRMED, Probabilidad: 0.7224
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8213
# Clase predicha: CONFIRMED, Probabilidad: 0.5241
# Clase predicha: CONFIRMED, Probabilidad: 0.6446
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9373
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5453
# Clase predicha: CONFIRMED, Probabilidad: 0.5670
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5154
# Clase predicha: CONFIRMED, Probabilidad: 0.7997
# Clase predicha: CONFIRMED, Probabilidad: 0.7052
# Clase predicha: CONFIRMED, Probabilidad: 0.8986
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9207
# Clase predicha: CONFIRMED, Probabilidad: 0.7381
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5566
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9153
# Clase predicha: CONFIRMED, Probabilidad: 0.6182
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7101
# Clase predicha: CONFIRMED, Probabilidad: 0.7348
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7485
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5858
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9372
# Clase predicha: CONFIRMED, Probabilidad: 0.7193
# Clase predicha: CONFIRMED, Probabilidad: 0.7149
# Clase predicha: CONFIRMED, Probabilidad: 0.7821
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6482
# Clase predicha: CONFIRMED, Probabilidad: 0.8557
# Clase predicha: CONFIRMED, Probabilidad: 0.6623
# Clase predicha: CONFIRMED, Probabilidad: 0.7216
# Clase predicha: CONFIRMED, Probabilidad: 0.6714
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6717
# Clase predicha: CONFIRMED, Probabilidad: 0.7071
# Clase predicha: CONFIRMED, Probabilidad: 0.6679
# Clase predicha: CONFIRMED, Probabilidad: 0.7104
# Clase predicha: CONFIRMED, Probabilidad: 0.7620
# Clase predicha: CONFIRMED, Probabilidad: 0.6403
# Clase predicha: CONFIRMED, Probabilidad: 0.5570
# Clase predicha: CONFIRMED, Probabilidad: 0.6554
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6484
# Clase predicha: CONFIRMED, Probabilidad: 0.6208
# Clase predicha: CONFIRMED, Probabilidad: 0.7567
# Clase predicha: CONFIRMED, Probabilidad: 0.5257
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5169
# Clase predicha: CONFIRMED, Probabilidad: 0.8235
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6582
# Clase predicha: CONFIRMED, Probabilidad: 0.8867
# Clase predicha: CONFIRMED, Probabilidad: 0.5416
# Clase predicha: CONFIRMED, Probabilidad: 0.7934
# Clase predicha: CONFIRMED, Probabilidad: 0.5986
# Clase predicha: CONFIRMED, Probabilidad: 0.6302
# Clase predicha: CONFIRMED, Probabilidad: 0.6838
# Clase predicha: CONFIRMED, Probabilidad: 0.7611
# Clase predicha: CONFIRMED, Probabilidad: 0.6243
# Clase predicha: CONFIRMED, Probabilidad: 0.7980
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5086
# Clase predicha: CONFIRMED, Probabilidad: 0.8879
# Clase predicha: CONFIRMED, Probabilidad: 0.6846
# Clase predicha: CONFIRMED, Probabilidad: 0.7867
# Clase predicha: CONFIRMED, Probabilidad: 0.5835
# Clase predicha: CONFIRMED, Probabilidad: 0.5865
# Clase predicha: CONFIRMED, Probabilidad: 0.7503
# Clase predicha: CONFIRMED, Probabilidad: 0.7418
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9138
# Clase predicha: CONFIRMED, Probabilidad: 0.5949
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5358
# Clase predicha: CONFIRMED, Probabilidad: 0.7274
# Clase predicha: CONFIRMED, Probabilidad: 0.5196
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8765
# Clase predicha: CONFIRMED, Probabilidad: 0.5710
# Clase predicha: CONFIRMED, Probabilidad: 0.5062
# Clase predicha: CONFIRMED, Probabilidad: 0.6357
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5230
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7774
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8815
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5106
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8206
# Clase predicha: CONFIRMED, Probabilidad: 0.7282
# Clase predicha: CONFIRMED, Probabilidad: 0.6494
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7496
# Clase predicha: CONFIRMED, Probabilidad: 0.7310
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8987
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7705
# Clase predicha: CONFIRMED, Probabilidad: 0.6488
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5894
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5050
# Clase predicha: CONFIRMED, Probabilidad: 0.6855
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8369
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9057
# Clase predicha: CONFIRMED, Probabilidad: 0.5485
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7605
# Clase predicha: CONFIRMED, Probabilidad: 0.9138
# Clase predicha: CONFIRMED, Probabilidad: 0.7706
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9209
# Clase predicha: CONFIRMED, Probabilidad: 0.6244
# Clase predicha: CONFIRMED, Probabilidad: 0.6209
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9711
# Clase predicha: CONFIRMED, Probabilidad: 0.6783
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9687
# Clase predicha: CONFIRMED, Probabilidad: 0.6821
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5197
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7620
# Clase predicha: CONFIRMED, Probabilidad: 0.7005
# Clase predicha: CONFIRMED, Probabilidad: 0.7813
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7685
# Clase predicha: CONFIRMED, Probabilidad: 0.7313
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9082
# Clase predicha: CONFIRMED, Probabilidad: 0.7768
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7996
# Clase predicha: CONFIRMED, Probabilidad: 0.7393
# Clase predicha: CONFIRMED, Probabilidad: 0.5818
# Clase predicha: CONFIRMED, Probabilidad: 0.7373
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8627
# Clase predicha: CONFIRMED, Probabilidad: 0.7575
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7508
# Clase predicha: CONFIRMED, Probabilidad: 0.7860
# Clase predicha: CONFIRMED, Probabilidad: 0.7648
# Clase predicha: CONFIRMED, Probabilidad: 0.7935
# Clase predicha: CONFIRMED, Probabilidad: 0.7899
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7184
# Clase predicha: CONFIRMED, Probabilidad: 0.5816
# Clase predicha: CONFIRMED, Probabilidad: 0.7076
# Clase predicha: CONFIRMED, Probabilidad: 0.7745
# Clase predicha: CONFIRMED, Probabilidad: 0.8315
# Clase predicha: CONFIRMED, Probabilidad: 0.7845
# Clase predicha: CONFIRMED, Probabilidad: 0.6746
# Clase predicha: CONFIRMED, Probabilidad: 0.6493
# Clase predicha: CONFIRMED, Probabilidad: 0.7246
# Clase predicha: CONFIRMED, Probabilidad: 0.7630
# Clase predicha: CONFIRMED, Probabilidad: 0.7779
# Clase predicha: CONFIRMED, Probabilidad: 0.6666
# Clase predicha: CONFIRMED, Probabilidad: 0.7178
# Clase predicha: CONFIRMED, Probabilidad: 0.7804
# Clase predicha: CONFIRMED, Probabilidad: 0.5321
# Clase predicha: CONFIRMED, Probabilidad: 0.6119
# Clase predicha: CONFIRMED, Probabilidad: 0.8016
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9912
# Clase predicha: CONFIRMED, Probabilidad: 0.7007
# Clase predicha: CONFIRMED, Probabilidad: 0.8130
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6986
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7782
# Clase predicha: CONFIRMED, Probabilidad: 0.8632
# Clase predicha: CONFIRMED, Probabilidad: 0.8443
# Clase predicha: CONFIRMED, Probabilidad: 0.8167
# Clase predicha: CONFIRMED, Probabilidad: 0.9719
# Clase predicha: CONFIRMED, Probabilidad: 0.6974
# Clase predicha: CONFIRMED, Probabilidad: 0.5897
# Clase predicha: CONFIRMED, Probabilidad: 0.9894
# Clase predicha: CONFIRMED, Probabilidad: 0.6874
# Clase predicha: CONFIRMED, Probabilidad: 0.8663
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6742
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6968
# Clase predicha: CONFIRMED, Probabilidad: 0.9184
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9061
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7347
# Clase predicha: CONFIRMED, Probabilidad: 0.6959
# Clase predicha: CONFIRMED, Probabilidad: 0.8724
# Clase predicha: CONFIRMED, Probabilidad: 0.9830
# Clase predicha: CONFIRMED, Probabilidad: 0.7837
# Clase predicha: CONFIRMED, Probabilidad: 0.8578
# Clase predicha: CONFIRMED, Probabilidad: 0.6576
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6231
# Clase predicha: CONFIRMED, Probabilidad: 0.6507
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9303
# Clase predicha: CONFIRMED, Probabilidad: 0.7157
# Clase predicha: CONFIRMED, Probabilidad: 0.9243
# Clase predicha: CONFIRMED, Probabilidad: 0.9929
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6942
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8894
# Clase predicha: CONFIRMED, Probabilidad: 0.9709
# Clase predicha: CONFIRMED, Probabilidad: 0.8943
# Clase predicha: CONFIRMED, Probabilidad: 0.6164
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5235
# Clase predicha: CONFIRMED, Probabilidad: 0.5224
# Clase predicha: CONFIRMED, Probabilidad: 0.5064
# Clase predicha: CONFIRMED, Probabilidad: 0.8162
# Clase predicha: CONFIRMED, Probabilidad: 0.5659
# Clase predicha: CONFIRMED, Probabilidad: 0.7857
# Clase predicha: CONFIRMED, Probabilidad: 0.6173
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7646
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6589
# Clase predicha: CONFIRMED, Probabilidad: 0.8916
# Clase predicha: CONFIRMED, Probabilidad: 0.8782
# Clase predicha: CONFIRMED, Probabilidad: 0.5415
# Clase predicha: CONFIRMED, Probabilidad: 0.6130
# Clase predicha: CONFIRMED, Probabilidad: 0.8402
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8851
# Clase predicha: CONFIRMED, Probabilidad: 0.6237
# Clase predicha: CONFIRMED, Probabilidad: 0.6768
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9363
# Clase predicha: CONFIRMED, Probabilidad: 0.6780
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5561
# Clase predicha: CONFIRMED, Probabilidad: 0.7428
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6887
# Clase predicha: CONFIRMED, Probabilidad: 0.7725
# Clase predicha: CONFIRMED, Probabilidad: 0.6977
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5938
# Clase predicha: CONFIRMED, Probabilidad: 0.5118
# Clase predicha: CONFIRMED, Probabilidad: 0.7347
# Clase predicha: CONFIRMED, Probabilidad: 0.7015
# Clase predicha: CONFIRMED, Probabilidad: 0.9950
# Clase predicha: CONFIRMED, Probabilidad: 0.7336
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9754
# Clase predicha: CONFIRMED, Probabilidad: 0.7833
# Clase predicha: CONFIRMED, Probabilidad: 0.7007
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8269
# Clase predicha: CONFIRMED, Probabilidad: 0.6196
# Clase predicha: CONFIRMED, Probabilidad: 0.5033
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8977
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.8627
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.7392
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5426
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9296
# Clase predicha: CONFIRMED, Probabilidad: 0.7288
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9191
# Clase predicha: CONFIRMED, Probabilidad: 0.6851
# Clase predicha: CONFIRMED, Probabilidad: 0.9596
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5026
# Clase predicha: CONFIRMED, Probabilidad: 0.8991
# Clase predicha: CONFIRMED, Probabilidad: 0.8449
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.5594
# Clase predicha: CONFIRMED, Probabilidad: 0.8196
# Clase predicha: CONFIRMED, Probabilidad: 0.6671
# Clase predicha: CONFIRMED, Probabilidad: 0.5591
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9563
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9663
# Clase predicha: CONFIRMED, Probabilidad: 0.7077
# Clase predicha: CONFIRMED, Probabilidad: 0.5309
# Clase predicha: CONFIRMED, Probabilidad: 0.7302
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.6695
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9697
# Clase predicha: FALSE POSITIVE, Probabilidad: 0.9307

# %% [markdown]
# ## Guardar el modelo

# %%
model.save('modelo_red_toi.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.export('modelo_toi')
# Out:
# INFO:tensorflow:Assets written to: modelo_toi\assets
# INFO:tensorflow:Assets written to: modelo_toi\assets
# Saved artifact at 'modelo_toi'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 20), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2639412686352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412687120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412686160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412688656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412687504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412688848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412686736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412686544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412689616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412690192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412687312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2639412690576: TensorSpec(shape=(), dtype=tf.resource, name=None)
